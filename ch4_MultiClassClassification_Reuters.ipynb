# %% [markdown]
# ### Classifying newswires: A multiclass classification example

# %% [markdown]
# #### The Reuters dataset

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[10]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(decoded_newswire)
# Out:
# ? period ended december 31 shr profit 11 cts vs loss 24 cts net profit 224 271 vs loss 511 349 revs 7 258 688 vs 7 200 349 reuter 3

# %%
train_labels[10]
# Out:
# np.int64(3)

# %% [markdown]
# #### Preparing the data

# %%
import numpy as np

def multi_hot_encode(sequences, num_classes):
    results = np.zeros((len(sequences), num_classes))
    for i, sequence in enumerate(sequences):
        results[i][sequence] = 1.0
    return results

# Vectorized training data
x_train = multi_hot_encode(train_data, num_classes=10000)

# Vectorized test data
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
def one_hot_encode(labels, num_classes=46):
    results = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        results[i, label] = 1.0
    return results

y_train = one_hot_encode(train_labels)
y_test = one_hot_encode(test_labels)

# %% [markdown]
# Or use to_categorical from keras

# %%
from keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)

# %%
top_3_accuracy = keras.metrics.TopKCategoricalAccuracy(
    k=3, name="top_3_accuracy"
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy", top_3_accuracy],
)

# %% [markdown]
# #### Validating your approach

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.3017 - loss: 3.6186 - top_3_accuracy: 0.4124 - val_accuracy: 0.5710 - val_loss: 2.6622 - val_top_3_accuracy: 0.7010
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6202 - loss: 2.2928 - top_3_accuracy: 0.7281 - val_accuracy: 0.6610 - val_loss: 1.6785 - val_top_3_accuracy: 0.7600
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7099 - loss: 1.4387 - top_3_accuracy: 0.8003 - val_accuracy: 0.7110 - val_loss: 1.2843 - val_top_3_accuracy: 0.8220
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7753 - loss: 1.0763 - top_3_accuracy: 0.8634 - val_accuracy: 0.7600 - val_loss: 1.1114 - val_top_3_accuracy: 0.8570
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8290 - loss: 0.8223 - top_3_accuracy: 0.9129 - val_accuracy: 0.7950 - val_loss: 1.0073 - val_top_3_accuracy: 0.8920
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8629 - loss: 0.6576 - top_3_accuracy: 0.9423 - val_accuracy: 0.8010 - val_loss: 0.9536 - val_top_3_accuracy: 0.9000
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8971 - loss: 0.4986 - top_3_accuracy: 0.9616 - val_accuracy: 0.8070 - val_loss: 0.9026 - val_top_3_accuracy: 0.9130
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9206 - loss: 0.3852 - top_3_accuracy: 0.9792 - val_accuracy: 0.8250 - val_loss: 0.8826 - val_top_3_accuracy: 0.9180
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9358 - loss: 0.3041 - top_3_accuracy: 0.9870 - val_accuracy: 0.8250 - val_loss: 0.8718 - val_top_3_accuracy: 0.9170
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9444 - loss: 0.2466 - top_3_accuracy: 0.9921 - val_accuracy: 0.8280 - val_loss: 0.8762 - val_top_3_accuracy: 0.9190
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9564 - loss: 0.2017 - top_3_accuracy: 0.9948 - val_accuracy: 0.8180 - val_loss: 0.9078 - val_top_3_accuracy: 0.9210
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9574 - loss: 0.1777 - top_3_accuracy: 0.9962 - val_accuracy: 0.8090 - val_loss: 0.9172 - val_top_3_accuracy: 0.9240
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9585 - loss: 0.1509 - top_3_accuracy: 0.9975 - val_accuracy: 0.8250 - val_loss: 0.9059 - val_top_3_accuracy: 0.9220
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9564 - loss: 0.1444 - top_3_accuracy: 0.9975 - val_accuracy: 0.8150 - val_loss: 0.9390 - val_top_3_accuracy: 0.9230
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9590 - loss: 0.1287 - top_3_accuracy: 0.9981 - val_accuracy: 0.8190 - val_loss: 0.9354 - val_top_3_accuracy: 0.9220
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9628 - loss: 0.1130 - top_3_accuracy: 0.9989 - val_accuracy: 0.8070 - val_loss: 0.9827 - val_top_3_accuracy: 0.9230
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9631 - loss: 0.1109 - top_3_accuracy: 0.9986 - val_accuracy: 0.8100 - val_loss: 0.9603 - val_top_3_accuracy: 0.9280
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9630 - loss: 0.1032 - top_3_accuracy: 0.9989 - val_accuracy: 0.8160 - val_loss: 0.9839 - val_top_3_accuracy: 0.9210
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9676 - loss: 0.0933 - top_3_accuracy: 0.9987 - val_accuracy: 0.8160 - val_loss: 0.9893 - val_top_3_accuracy: 0.9270
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9637 - loss: 0.0945 - top_3_accuracy: 0.9993 - val_accuracy: 0.8110 - val_loss: 1.0040 - val_top_3_accuracy: 0.9250

# %%
import matplotlib.pyplot as plt

loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["top_3_accuracy"]
val_acc = history.history["val_top_3_accuracy"]
plt.plot(epochs, acc, "r--", label="Training top-3 accuracy")
plt.plot(epochs, val_acc, "b", label="Validation top-3 accuracy")
plt.title("Training and validation top-3 accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Top-3 accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    x_train,
    y_train,
    epochs=9,
    batch_size=512,
)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.2679 - loss: 3.5911
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5854 - loss: 2.1879
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7007 - loss: 1.3643
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7708 - loss: 1.0363
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8229 - loss: 0.8098
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8625 - loss: 0.6300
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9034 - loss: 0.4791
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9250 - loss: 0.3644
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9372 - loss: 0.2909
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8089 - loss: 0.8854

# %%
results
# Out:
# [0.908495306968689, 0.8018699884414673]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels == test_labels_copy)
hits_array.mean()
# Out:
# np.float64(0.19545859305431879)

# %% [markdown]
# #### Generating predictions on new data

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.argmax(predictions[0])
# Out:
# np.int64(3)

# %% [markdown]
# #### A different way to handle the labels and the loss

# %%
y_train = train_labels
y_test = test_labels

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### The importance of having sufficiently large intermediate layers

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(4, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.0288 - loss: 3.7015 - val_accuracy: 0.3920 - val_loss: 3.1789
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4296 - loss: 2.8520 - val_accuracy: 0.4290 - val_loss: 2.3390
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4268 - loss: 2.1610 - val_accuracy: 0.4590 - val_loss: 1.9218
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5769 - loss: 1.5229 - val_accuracy: 0.6850 - val_loss: 1.3855
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7350 - loss: 1.0777 - val_accuracy: 0.6990 - val_loss: 1.3340
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.8897 - val_accuracy: 0.7070 - val_loss: 1.3311
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8001 - loss: 0.7944 - val_accuracy: 0.7100 - val_loss: 1.3553
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8181 - loss: 0.7155 - val_accuracy: 0.7060 - val_loss: 1.3858
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8304 - loss: 0.6460 - val_accuracy: 0.7030 - val_loss: 1.4332
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8490 - loss: 0.5907 - val_accuracy: 0.7060 - val_loss: 1.4701
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8455 - loss: 0.5735 - val_accuracy: 0.7020 - val_loss: 1.5296
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8539 - loss: 0.5396 - val_accuracy: 0.6980 - val_loss: 1.6005
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8611 - loss: 0.4932 - val_accuracy: 0.7080 - val_loss: 1.6236
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8717 - loss: 0.4672 - val_accuracy: 0.7010 - val_loss: 1.6667
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8800 - loss: 0.4471 - val_accuracy: 0.7070 - val_loss: 1.7563
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8865 - loss: 0.4340 - val_accuracy: 0.7090 - val_loss: 1.7800
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8957 - loss: 0.4041 - val_accuracy: 0.7020 - val_loss: 1.8692
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8933 - loss: 0.4145 - val_accuracy: 0.7130 - val_loss: 1.9112
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8962 - loss: 0.3792 - val_accuracy: 0.7030 - val_loss: 1.9247
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9020 - loss: 0.3615 - val_accuracy: 0.7030 - val_loss: 1.9809
